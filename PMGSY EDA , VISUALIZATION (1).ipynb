# %% [markdown]
# ### install pandas

# %%
# !pip install pandas

# %% [markdown]
# ### importing pandas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### reading the file

# %%
trisha=pd.read_csv("PROJECT DATA .csv")
trisha
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1     Andhra Pradesh             Anakapalli     PMGSY-II
# 2     Andhra Pradesh                Bapatla    PMGSY-III
# 3     Andhra Pradesh                  Eluru      PMGSY-I
# 4     Andhra Pradesh                  Eluru    PMGSY-III
# ...              ...                    ...          ...
# 2240     West Bengal            Murshidabad      PMGSY-I
# 2241     West Bengal                  Nadia    PMGSY-III
# 2242     West Bengal        Paschim Burdwan    PMGSY-III
# 2243     West Bengal          Siliguri M.P.    PMGSY-III
# 2244     West Bengal      South 24-Parganas     PMGSY-II
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                            124                        34
# 1                              5                         0
# 2                             12                         3
# ...

# %% [markdown]
# ### version

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ### DISPLAY THE FIRST FEW ROWS

# %%
trisha.head()
# Out:
#        STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 0  Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1  Andhra Pradesh             Anakapalli     PMGSY-II
# 2  Andhra Pradesh                Bapatla    PMGSY-III
# 3  Andhra Pradesh                  Eluru      PMGSY-I
# 4  Andhra Pradesh                  Eluru    PMGSY-III
#
#    NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                         124                        34
# 1                           5                         0
# 2                          12                         3
# 3                         175                         2
# 4                          12                         2
#
#    NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 0                          99                       18
# 1                           5                        0
# 2                           3                        0
# 3                         175                        2
# ...

# %% [markdown]
# ### display last few rows

# %%
trisha.tail()
# Out:
#        STATE_NAME      DISTRICT_NAME PMGSY_SCHEME  NO_OF_ROAD_WORK_SANCTIONED  \
# 2240  West Bengal        Murshidabad      PMGSY-I                         410
# 2241  West Bengal              Nadia    PMGSY-III                          13
# 2242  West Bengal    Paschim Burdwan    PMGSY-III                           7
# 2243  West Bengal      Siliguri M.P.    PMGSY-III                           2
# 2244  West Bengal  South 24-Parganas     PMGSY-II                          29
#
#       NO_OF_BRIDGES_SANCTIONED  NO_OF_ROAD_WORKS_COMPLETED  \
# 2240                         4                         410
# 2241                         0                           5
# 2242                         0                           3
# 2243                         0                           0
# 2244                         0                          29
#
#       NO_OF_BRIDGES_COMPLETED  NO_OF_ROAD_WORKS_BALANCE  \
# 2240                        4                         0
# ...

# %%
#to view the dimensions of the data
trisha.shape
# Out:
# (2245, 14)

# %%
# Displays column names present in the data
trisha.columns
# Out:
# Index(['STATE_NAME', 'DISTRICT_NAME', 'PMGSY_SCHEME',
#        'NO_OF_ROAD_WORK_SANCTIONED', 'NO_OF_BRIDGES_SANCTIONED',
#        'NO_OF_ROAD_WORKS_COMPLETED', 'NO_OF_BRIDGES_COMPLETED',
#        'NO_OF_ROAD_WORKS_BALANCE', 'NO_OF_BRIDGES_BALANCE',
#        'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS',
#        'LENGTH_OF_ROAD_WORK_COMPLETED_KM', 'EXPENDITURE_OCCURED_LAKHS',
#        'LENGTH_OF_ROAD_WORK_BALANCE_KM'],
#       dtype='object')

# %%
# Displays data type of each column of the dataset
trisha.dtypes
# Out:
# STATE_NAME                            object
# DISTRICT_NAME                         object
# PMGSY_SCHEME                          object
# NO_OF_ROAD_WORK_SANCTIONED             int64
# NO_OF_BRIDGES_SANCTIONED               int64
# NO_OF_ROAD_WORKS_COMPLETED             int64
# NO_OF_BRIDGES_COMPLETED                int64
# NO_OF_ROAD_WORKS_BALANCE               int64
# NO_OF_BRIDGES_BALANCE                  int64
# LENGTH_OF_ROAD_WORK_SANCTIONED_KM    float64
# COST_OF_WORKS_SANCTIONED_LAKHS       float64
# LENGTH_OF_ROAD_WORK_COMPLETED_KM     float64
# EXPENDITURE_OCCURED_LAKHS            float64
# LENGTH_OF_ROAD_WORK_BALANCE_KM       float64
# dtype: object

# %%
# Displays statistical description
trisha.describe()
# Out:
#        NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# count                 2245.000000               2245.000000
# mean                    84.096659                  5.293096
# std                    146.867151                 13.264704
# min                      0.000000                  0.000000
# 25%                      9.000000                  0.000000
# 50%                     19.000000                  0.000000
# 75%                     88.000000                  4.000000
# max                   1263.000000                220.000000
#
#        NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# count                 2245.000000              2245.000000
# mean                    80.478396                 4.057906
# std                    147.468738                11.905871
# min                      0.000000                 0.000000
# 25%                      5.000000                 0.000000
# 50%                     14.000000                 0.000000
# ...

# %%
# Gives information of the data such as index, column names, if there are null values in ant rows etc..
trisha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245 entries, 0 to 2244
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   STATE_NAME                         2245 non-null   object
#  1   DISTRICT_NAME                      2245 non-null   object
#  2   PMGSY_SCHEME                       2245 non-null   object
#  3   NO_OF_ROAD_WORK_SANCTIONED         2245 non-null   int64
#  4   NO_OF_BRIDGES_SANCTIONED           2245 non-null   int64
#  5   NO_OF_ROAD_WORKS_COMPLETED         2245 non-null   int64
#  6   NO_OF_BRIDGES_COMPLETED            2245 non-null   int64
#  7   NO_OF_ROAD_WORKS_BALANCE           2245 non-null   int64
#  8   NO_OF_BRIDGES_BALANCE              2245 non-null   int64
#  9   LENGTH_OF_ROAD_WORK_SANCTIONED_KM  2245 non-null   float64
#  10  COST_OF_WORKS_SANCTIONED_LAKHS     2245 non-null   float64
# ...

# %%
# Displays the data in particular column
trisha["STATE_NAME"]
# Out:
# 0       Andhra Pradesh
# 1       Andhra Pradesh
# 2       Andhra Pradesh
# 3       Andhra Pradesh
# 4       Andhra Pradesh
#              ...
# 2240       West Bengal
# 2241       West Bengal
# 2242       West Bengal
# 2243       West Bengal
# 2244       West Bengal
# Name: STATE_NAME, Length: 2245, dtype: object

# %% [markdown]
# ### accessing multiple graph

# %%
trisha[["STATE_NAME","DISTRICT_NAME","PMGSY_SCHEME"]]
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME
# 0     Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1     Andhra Pradesh             Anakapalli     PMGSY-II
# 2     Andhra Pradesh                Bapatla    PMGSY-III
# 3     Andhra Pradesh                  Eluru      PMGSY-I
# 4     Andhra Pradesh                  Eluru    PMGSY-III
# ...              ...                    ...          ...
# 2240     West Bengal            Murshidabad      PMGSY-I
# 2241     West Bengal                  Nadia    PMGSY-III
# 2242     West Bengal        Paschim Burdwan    PMGSY-III
# 2243     West Bengal          Siliguri M.P.    PMGSY-III
# 2244     West Bengal      South 24-Parganas     PMGSY-II
#
# [2245 rows x 3 columns]

# %%
trisha2 = trisha[["STATE_NAME","DISTRICT_NAME"]]
trisha2
# Out:
#           STATE_NAME          DISTRICT_NAME
# 0     Andhra Pradesh  Alluri Sitharama Raju
# 1     Andhra Pradesh             Anakapalli
# 2     Andhra Pradesh                Bapatla
# 3     Andhra Pradesh                  Eluru
# 4     Andhra Pradesh                  Eluru
# ...              ...                    ...
# 2240     West Bengal            Murshidabad
# 2241     West Bengal                  Nadia
# 2242     West Bengal        Paschim Burdwan
# 2243     West Bengal          Siliguri M.P.
# 2244     West Bengal      South 24-Parganas
#
# [2245 rows x 2 columns]

# %% [markdown]
# ### index

# %%
trisha.index
# Out:
# RangeIndex(start=0, stop=2245, step=1)

# %%
trisha.index.is_unique
# Out:
# True

# %%
trisha["DISTRICT_NAME"].unique
# Out:
# <bound method Series.unique of 0       Alluri Sitharama Raju
# 1                  Anakapalli
# 2                     Bapatla
# 3                       Eluru
# 4                       Eluru
#                 ...
# 2240              Murshidabad
# 2241                    Nadia
# 2242          Paschim Burdwan
# 2243            Siliguri M.P.
# 2244        South 24-Parganas
# Name: DISTRICT_NAME, Length: 2245, dtype: object>

# %%
trisha["STATE_NAME"].value_counts()
# Out:
# STATE_NAME
# Uttar Pradesh          227
# Madhya Pradesh         175
# Rajasthan              145
# Bihar                  121
# Tamil Nadu             110
# Chhattisgarh           106
# Maharashtra            104
# Telangana              103
# Odisha                 101
# Gujarat                 99
# Jharkhand               98
# Karnataka               94
# Andhra Pradesh          87
# Assam                   73
# Arunachal Pradesh       71
# West Bengal             65
# Haryana                 62
# Punjab                  62
# Jammu And Kashmir       60
# Kerala                  42
# Uttarakhand             39
# Himachal Pradesh        36
# Nagaland                33
# Tripura                 30
# Manipur                 27
# Meghalaya               21
# Mizoram                 21
# Sikkim                  18
# Ladakh                   6
# Andaman And Nicobar      5
# Puducherry               2
# Goa                      2
# Name: count, dtype: int64

# %%
a = trisha[(trisha["DISTRICT_NAME"] == "Eluru") & (trisha["NO_OF_ROAD_WORKS_COMPLETED"] >= 100)]

# %%
a["NO_OF_ROAD_WORK_SANCTIONED"].value_counts()
# Out:
# NO_OF_ROAD_WORK_SANCTIONED
# 175    1
# Name: count, dtype: int64

# %%
trisha["BALANCE_AMOUNT"] = trisha["COST_OF_WORKS_SANCTIONED_LAKHS"] - trisha["EXPENDITURE_OCCURED_LAKHS"]
trisha
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1     Andhra Pradesh             Anakapalli     PMGSY-II
# 2     Andhra Pradesh                Bapatla    PMGSY-III
# 3     Andhra Pradesh                  Eluru      PMGSY-I
# 4     Andhra Pradesh                  Eluru    PMGSY-III
# ...              ...                    ...          ...
# 2240     West Bengal            Murshidabad      PMGSY-I
# 2241     West Bengal                  Nadia    PMGSY-III
# 2242     West Bengal        Paschim Burdwan    PMGSY-III
# 2243     West Bengal          Siliguri M.P.    PMGSY-III
# 2244     West Bengal      South 24-Parganas     PMGSY-II
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                            124                        34
# 1                              5                         0
# 2                             12                         3
# ...

# %%
#rename

# %%
trisha.rename(columns={"BALANCE_AMOUNT" : "BALANCE_AMOUNT_IN_LAKHS"}, inplace = True)
trisha
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1     Andhra Pradesh             Anakapalli     PMGSY-II
# 2     Andhra Pradesh                Bapatla    PMGSY-III
# 3     Andhra Pradesh                  Eluru      PMGSY-I
# 4     Andhra Pradesh                  Eluru    PMGSY-III
# ...              ...                    ...          ...
# 2240     West Bengal            Murshidabad      PMGSY-I
# 2241     West Bengal                  Nadia    PMGSY-III
# 2242     West Bengal        Paschim Burdwan    PMGSY-III
# 2243     West Bengal          Siliguri M.P.    PMGSY-III
# 2244     West Bengal      South 24-Parganas     PMGSY-II
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                            124                        34
# 1                              5                         0
# 2                             12                         3
# ...

# %%
b = trisha.groupby(["STATE_NAME", "DISTRICT_NAME"]).size()
print(b)
# Out:
# STATE_NAME           DISTRICT_NAME
# Andaman And Nicobar  Nicobar                     1
#                      North and Middle Andaman    2
#                      South Andaman               2
# Andhra Pradesh       Alluri Sitharama Raju       5
#                      Anakapalli                  3
#                                                 ..
# West Bengal          Purba Medinipur             2
#                      Purulia                     3
#                      Siliguri M.P.               3
#                      South 24-Parganas           3
#                      Uttardinajpur               3
# Length: 721, dtype: int64

# %%
#handling missing values
trisha.isnull()
# Out:
#       STATE_NAME  DISTRICT_NAME  PMGSY_SCHEME  NO_OF_ROAD_WORK_SANCTIONED  \
# 0          False          False         False                       False
# 1          False          False         False                       False
# 2          False          False         False                       False
# 3          False          False         False                       False
# 4          False          False         False                       False
# ...          ...            ...           ...                         ...
# 2240       False          False         False                       False
# 2241       False          False         False                       False
# 2242       False          False         False                       False
# 2243       False          False         False                       False
# 2244       False          False         False                       False
#
#       NO_OF_BRIDGES_SANCTIONED  NO_OF_ROAD_WORKS_COMPLETED  \
# ...

# %% [markdown]
# ### INSIGHTS

# %% [markdown]
# ### 1 Which state has sanctioned the highest number of road works?

# %%
group1 = trisha.groupby("STATE_NAME").agg({"NO_OF_ROAD_WORK_SANCTIONED": "sum"})
group2 = group1.sort_values(by="NO_OF_ROAD_WORK_SANCTIONED", ascending=False)
group2
# Out:
#                      NO_OF_ROAD_WORK_SANCTIONED
# STATE_NAME
# Uttar Pradesh                             21124
# Madhya Pradesh                            20661
# Bihar                                     18771
# Rajasthan                                 18156
# Odisha                                    17937
# Tamil Nadu                                10352
# Chhattisgarh                               9327
# Assam                                      9269
# Jharkhand                                  8192
# West Bengal                                7371
# Maharashtra                                6930
# Andhra Pradesh                             5340
# Gujarat                                    4828
# Karnataka                                  4434
# Himachal Pradesh                           3877
# Telangana                                  3570
# Jammu And Kashmir                          3437
# Uttarakhand                                2620
# ...

# %%
# Plot
plt.figure(figsize=(10,6))
group2.plot(kind="bar", legend=False, color="green", edgecolor="black", width=0.8)
plt.title('Number of Sanctioned Road Works by State')
plt.xlabel('State')
plt.ylabel('Number of Sanctioned Road Works')
plt.xticks(rotation=45, ha="right", fontsize = 7) 
plt.tight_layout() 
plt.show()

# %% [markdown]
# Inference:
# The bar chart illustrates the Number of Road Works Sanctioned by State. From the chart:
# •
# Uttar Pradesh has the highest number of road works sanctioned, with around 20,000 projects.
# •
# Madhya Pradesh, Bihar, and Rajasthan follow closely behind, each with between 15,000 and 19,000 sanctioned road works.
# •
# States like Haryana, Nagaland, Mizoram, Ladakh, Andaman and Nicobar Islands, Goa, and Puducherry have significantly fewer sanctioned road works, below 1,000.
# •
# There is a wide disparity in the number of road works sanctioned between states, highlighting different levels of infrastructure focus or project prioritization.
# Result:
# The state with the highest number of road works sanctioned is Uttar Pradesh, followed by Madhya Pradesh, Bihar, and Rajasthan.

# %% [markdown]
# ### 2 Which state has completed the highest percentage of sanctioned road works?

# %%
# Calculate completion percentage
trisha['COMPLETION_PERCENTAGE'] = (trisha['NO_OF_ROAD_WORKS_COMPLETED'] / trisha['NO_OF_ROAD_WORK_SANCTIONED']) * 100
trisha
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andhra Pradesh  Alluri Sitharama Raju      RCPLWEA
# 1     Andhra Pradesh             Anakapalli     PMGSY-II
# 2     Andhra Pradesh                Bapatla    PMGSY-III
# 3     Andhra Pradesh                  Eluru      PMGSY-I
# 4     Andhra Pradesh                  Eluru    PMGSY-III
# ...              ...                    ...          ...
# 2240     West Bengal            Murshidabad      PMGSY-I
# 2241     West Bengal                  Nadia    PMGSY-III
# 2242     West Bengal        Paschim Burdwan    PMGSY-III
# 2243     West Bengal          Siliguri M.P.    PMGSY-III
# 2244     West Bengal      South 24-Parganas     PMGSY-II
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                            124                        34
# 1                              5                         0
# 2                             12                         3
# ...

# %%
# Group by state and calculate the mean completion percentage
state_completion_percentage = trisha.groupby('STATE_NAME')['COMPLETION_PERCENTAGE'].mean()
state_completion_percentage
# Out:
# STATE_NAME
# Andaman And Nicobar     72.102273
# Andhra Pradesh          83.177173
# Arunachal Pradesh       65.164125
# Assam                   88.431600
# Bihar                   87.695407
# Chhattisgarh            81.826957
# Goa                    100.000000
# Gujarat                 95.820685
# Haryana                 97.492194
# Himachal Pradesh        65.982016
# Jammu And Kashmir       77.936150
# Jharkhand               71.382200
# Karnataka               92.871683
# Kerala                  70.185684
# Ladakh                  61.336981
# Madhya Pradesh          82.480803
# Maharashtra             78.946065
# Manipur                 55.654255
# Meghalaya               62.862343
# Mizoram                 54.886502
# Nagaland                60.839523
# Odisha                  83.548039
# Puducherry              65.732759
# Punjab                  84.592176
# Rajasthan               94.835382
# Sikkim                  57.485929
# Tamil Nadu              88.078364
# ...

# %%
#Find the state with the highest percentage
max_completion_state = state_completion_percentage.idxmax()
max_completion_value = state_completion_percentage.max()
print(f"State with highest completion percentage: {max_completion_state} ({max_completion_value:.2f}%)")
# Out:
# State with highest completion percentage: Goa (100.00%)

# %%
# Plot
plt.figure(figsize=(10,6))
state_completion_percentage.plot(kind='bar', color='green')
plt.title('Completion Percentage of Road Works by State')
plt.xlabel('State')
plt.ylabel('Completion Percentage (%)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Inference:
# Based on the chart, the states are ranked by the percentage of road works completed relative to those sanctioned. The chart shows that the majority of states are close to 100% completion. However, one state stands out with a completion rate significantly lower than the others, indicating a lag in progress.
# Result:
# From the chart, West Bengal appears to have the highest percentage of completed road works, reaching close to 100%, while several other states also demonstrate near-complete progress, indicated by full or nearly full bars in the graph.

# %% [markdown]
# ### 3. How does the number of sanctioned road works correlate with the number of road works completed?

# %%
# Plot a scatter plot to visualize the correlation
plt.figure(figsize=(8,6))
plt.scatter(trisha['NO_OF_ROAD_WORK_SANCTIONED'], trisha['NO_OF_ROAD_WORKS_COMPLETED'], color='green')
plt.title('Correlation Between Sanctioned and Completed Road Works')
plt.xlabel('Sanctioned Road Works')
plt.ylabel('Completed Road Works')
plt.grid(True)
plt.show()

# %%
 #Calculate correlation
correlation = trisha['NO_OF_ROAD_WORK_SANCTIONED'].corr(trisha['NO_OF_ROAD_WORKS_COMPLETED'])
print(f"Correlation between sanctioned and completed road works: {correlation}")
# Out:
# Correlation between sanctioned and completed road works: 0.9983679872942419

# %% [markdown]
# Inference:
# •
# The number of sanctioned road works directly influences the number of completed road works, as seen by the high correlation.
# •
# A perfect correlation (1.00) implies that the number of sanctioned and completed works are very tightly aligned, with little or no discrepancy between what is sanctioned and what gets completed.
# This visualization effectively communicates that road projects are being completed almost in line with the number of projects sanctioned.
# Result:
# The relationship between sanctioned and completed road works appears to be linear, with most points lying close to the line of best fit.

# %% [markdown]
# ### 4. Which state has the highest expenditure on road projects, and how does it compare with the number of roads completed?

# %%
q1 = trisha.groupby("STATE_NAME").agg({"EXPENDITURE_OCCURED_LAKHS": "sum","NO_OF_ROAD_WORKS_COMPLETED": "sum"})
q2 = q1.sort_values(by=["EXPENDITURE_OCCURED_LAKHS","NO_OF_ROAD_WORKS_COMPLETED"], ascending=False)
q2
# Out:
#                      EXPENDITURE_OCCURED_LAKHS  NO_OF_ROAD_WORKS_COMPLETED
# STATE_NAME
# Bihar                               34146.2555                       18258
# Odisha                              32752.6419                       17457
# Madhya Pradesh                      32746.6924                       20204
# Uttar Pradesh                       27288.1984                       20604
# Assam                               22769.4277                        9057
# West Bengal                         16855.8859                        7259
# Chhattisgarh                        16680.8116                        8573
# Rajasthan                           16538.5977                       17997
# Jharkhand                           13295.4559                        7732
# Jammu And Kashmir                   12426.9579                        3185
# Maharashtra                         11774.6018                        6332
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(q2.index,q2['EXPENDITURE_OCCURED_LAKHS'], color='blue', label='Expenditure (Lakhs)')
plt.xlabel('State')
plt.ylabel('Expenditure (Lakhs)', color='b')
plt.xticks(rotation=90)
ax2 = plt.twinx() 
ax2.plot(q2.index,q2['NO_OF_ROAD_WORKS_COMPLETED'], color='red', marker='o', label='Roads Completed')
ax2.set_ylabel('Number of Roads Completed', color='red')
plt.title('State-wise Expenditure on Road Projects and Number of Roads Completed')
plt.show()

# %% [markdown]
# Inference:
# •
# West Bengal has the highest expenditure on road projects, indicating a significant allocation of resources towards road infrastructure.
# •
# With 732 completed roads, the state's expenditure is aligned with a substantial number of road completions, suggesting that the higher expenditure is correlated with a high volume of completed projects.
# Result:
# •
# State with the highest expenditure: West Bengal, with an expenditure of 2004.87157 Lakhs.
# •
# Number of roads completed in West Bengal: 732

# %% [markdown]
# ### 5. What is the relationship between the length of road works sanctioned and the length completed across different states?

# %%
# Group by state and sum sanctioned and completed lengths
q3 = trisha.groupby("STATE_NAME").agg({"LENGTH_OF_ROAD_WORK_SANCTIONED_KM": "sum","LENGTH_OF_ROAD_WORK_COMPLETED_KM": "sum"})
q4 = q3.sort_values(by=["LENGTH_OF_ROAD_WORK_SANCTIONED_KM","LENGTH_OF_ROAD_WORK_COMPLETED_KM"], ascending=False)
q4
# Out:
#                      LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# STATE_NAME
# Madhya Pradesh                               94251.113
# Rajasthan                                    78208.958
# Uttar Pradesh                                77414.341
# Odisha                                       74661.602
# Bihar                                        65619.383
# Chhattisgarh                                 47202.167
# West Bengal                                  37659.528
# Jharkhand                                    33846.017
# Maharashtra                                  33771.147
# Assam                                        32911.499
# Tamil Nadu                                   26577.778
# Himachal Pradesh                             24977.616
# Karnataka                                    24227.794
# Uttarakhand                                  22552.110
# Jammu And Kashmir                            20801.433
# Andhra Pradesh                               20116.093
# ...

# %%
# Plot
q4.plot(kind='bar', figsize=(12,6), color=['blue', 'green'])
plt.title('Sanctioned vs Completed Road Lengths by State')
plt.xlabel('State')
plt.ylabel('Road Length (KM)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Inference:
# •
# West Bengal has the highest expenditure (2004.87 Lakhs) but a moderate number of completed roads (732) compared to other states. This suggests that, while a significant amount of funds are allocated, the number of completed projects is not proportionally high.
# •
# Uttar Pradesh and Bihar show a more efficient use of funds, with a higher number of completed roads relative to their expenditure.
# •
# Gujarat and Haryana have high expenditures but relatively fewer completed roads, indicating potential inefficiencies or delays in project execution.
# Result:
# •
# West Bengal leads in expenditure but does not have the highest number of completed roads, raising concerns about efficiency.
# •
# Uttar Pradesh and Bihar appear more cost-effective, completing more roads with less expenditure.
# •
# States like Gujarat and Haryana need to assess project management practices to improve road completion relative to the funds spent.

# %% [markdown]
# ### 6. Which state has the most road works left to be completed (balance)?

# %%
q5 = trisha.groupby("STATE_NAME").agg({"NO_OF_ROAD_WORKS_BALANCE": "sum"})
q6 = q5.sort_values(by="NO_OF_ROAD_WORKS_BALANCE",ascending=False)

q7 = q6.iloc[0]
q8 = pd.DataFrame([q7.head(1)])
q8
# Out:
#               NO_OF_ROAD_WORKS_BALANCE
# Chhattisgarh                       754

# %%
# Plot
plt.figure(figsize=(10,6))
q8.plot(kind='bar', color='red')
plt.title('Balance of Road Works by State')
plt.xlabel('State')
plt.ylabel('Road Works Balance')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Inference:
# •
# The data is grouped by State Name and the total number of road works left to be completed is summed for each state.
# •
# The grouped data has been arranged in ascending order and plotting a bar graph for the same that helps to identify the States that has the maximum number of pending road works
# Result:
# •
# Goa has no road works left to be completed that implies Goa has completed all the roadworks as sanctioned.
# •
# Tamil Nadu and Chhattisgarh having the maximum number of road works pending to be completed, indicating potential delays in project execution or maybe shortage of funds as well. Chhattisgarh having a balance of 754 works to be completed and Tamil Nadu having 692 pending road works.

# %% [markdown]
# ### 7 Which PMGSY scheme type has the highest cost of works sanctioned?

# %%
q9 = trisha.groupby("PMGSY_SCHEME").agg({"COST_OF_WORKS_SANCTIONED_LAKHS": "sum"})
q10 = q9.sort_values(by="COST_OF_WORKS_SANCTIONED_LAKHS", ascending=False)

q10.head(1)
# Out:
#               COST_OF_WORKS_SANCTIONED_LAKHS
# PMGSY_SCHEME
# PMGSY-I                          250448.1078

# %%
# Plot
plt.figure(figsize=(8,6))
q10.plot(kind='bar', color='orange')
plt.title('Cost of Works Sanctioned by PMGSY Scheme')
plt.xlabel('Scheme')
plt.ylabel('Cost of Works Sanctioned (Lakhs)')
plt.show()

# %% [markdown]
# Inference:
# •
# The data is grouped by PMGSY scheme type and the cost sanctioned summed up for each scheme.
# •
# The plotting of bar graph for the same that helps to identify the Scheme type that has the maximum fund allotted for the road works sanctioned
# Result:
# •
# PMGSY-I scheme type has been allotted with maximum amount for the works sanctioned.
# •
# PM-JANMAN got minimum fund allotted for the road works sanctioned under the scheme.

# %% [markdown]
# ### 8 What is the average length of road works sanctioned across all districts, and how does it vary between districts?

# %%
average = trisha["LENGTH_OF_ROAD_WORK_SANCTIONED_KM"].mean()
q11 = trisha.groupby("DISTRICT_NAME").agg({"LENGTH_OF_ROAD_WORK_SANCTIONED_KM": "sum"})
q12 = q11.sort_values(by="LENGTH_OF_ROAD_WORK_SANCTIONED_KM", ascending=False)
top = q12.head()
top
# Out:
#                LENGTH_OF_ROAD_WORK_SANCTIONED_KM
# DISTRICT_NAME
# Mayurbhanj                              5637.067
# Koraput                                 4533.481
# Sundargarh                              4424.687
# Mandi                                   4410.370
# Udaipur                                 4357.802

# %%
# Plot
plt.figure(figsize=(10, 6))
bars = plt.barh(top.index, top["LENGTH_OF_ROAD_WORK_SANCTIONED_KM"], color="green")
plt.axvline(average, color="red", linestyle="--", label=f"Average Length: {average:.2f} KM")
plt.xlabel("Length of Road Work Sanctioned (KM)")
plt.ylabel("District Name")
plt.title("Top 5 Districts by Total Length of Road Work Sanctioned")
plt.legend()
plt.show()

# %% [markdown]
# ### 9 Which district has completed the most road work in terms of total kilometers?

# %%
q13= trisha.groupby("DISTRICT_NAME")["LENGTH_OF_ROAD_WORK_COMPLETED_KM"].sum().reset_index()
q14 = q13.loc[q13["LENGTH_OF_ROAD_WORK_COMPLETED_KM"].idxmax()]
q15 = pd.DataFrame([q14])
q15
# Out:
#     DISTRICT_NAME  LENGTH_OF_ROAD_WORK_COMPLETED_KM
# 413    Mayurbhanj                          5425.151

# %% [markdown]
# ### 10. Which state has the lowest ratio of expenditure to the cost of sanctioned works?

# %%
# Calculate the ratio of expenditure to sanctioned cost
trisha['EXPENDITURE_TO_COST_RATIO'] = trisha['EXPENDITURE_OCCURED_LAKHS'] / trisha['COST_OF_WORKS_SANCTIONED_LAKHS']

# Group by state and calculate the average ratio
state_ratio = trisha.groupby('STATE_NAME')['EXPENDITURE_TO_COST_RATIO'].mean()

# Find the state with the lowest ratio
min_ratio_state = state_ratio.idxmin()
min_ratio_value = state_ratio.min()
print(f"State with the lowest expenditure to sanctioned cost ratio: {min_ratio_state} ({min_ratio_value:.2f})")
# Out:
# State with the lowest expenditure to sanctioned cost ratio: Goa (0.00)

# %%
# Plot
plt.figure(figsize=(10,6))
state_ratio.plot(kind='bar', color='lightblue')
plt.title('Expenditure to Sanctioned Cost Ratio by State')
plt.xlabel('State')
plt.ylabel('Expenditure to Cost Ratio')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Inference:
# •
# The data is grouped by State Name and the expenditure that occurred for the road works and the cost that have been sanctioned for each state summed up.
# •
# The ratio column has been inserted to the grouped data and the ratio of each has been calculated.
# •
# The plotting of bar graph for the same that helps to identify the State which has the maximum and minimum ratio
# Result:
# •
# Goa and Andaman and Nicobar Islands have the lowest ratios of expenditure to sanctioned cost (around 0.4 and 0.5 respectively). This indicates that a smaller proportion of the sanctioned cost has been spent in these states, suggesting possible under-expenditure or delays in project implementation.
# •
# Karnataka, Assam, and Odisha are at the top of the chart, with a ratio close to or equal to 1. This means that nearly all of the sanctioned cost has been utilized.
